# %%
import xgboost as xgb
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import geoplot as gplt
import geoplot.crs as gcrs
from sklearn.model_selection import train_test_split
import contextily as cx

# %%
data = pd.read_csv('../data/us_life_expectancy.csv')

# %%
data
# Out:
#       cartodb_id  countyfp  statefp      statename  \
# 0             80        57       12        Florida
# 1            398       213       48          Texas
# 2            409       409       48          Texas
# 3            647         5       24       Maryland
# 4            712        31       13        Georgia
# ...          ...       ...      ...            ...
# 3979        4637       101       54  West Virginia
# 3980        4638       103       55      Wisconsin
# 3981        4639        21        8       Colorado
# 3982        4640        47       16          Idaho
# 3983        4642       131       31       Nebraska
#
#                          countyname  countyfips  \
# 0      Hillsborough County, Florida       12057
# 1           Henderson County, Texas       48213
# 2        San Patricio County, Texas       48409
# 3        Baltimore County, Maryland       24005
# 4           Bulloch County, Georgia       13031
# ...                             ...         ...
# 3979  Webster County, West Virginia       54101
# 3980     Richland County, Wisconsin       55103
# 3981       Conejos County, Colorado        8021
# 3982          Gooding County, Idaho       16047
# 3983          Otoe County, Nebraska       31131
#
#                                               tractname  ratio  statemhir  \
# 0     Census Tract 108.14, Hillsborough County, Florida  0.575      47212
# 1         Census Tract 9509.01, Henderson County, Texas  0.752      52576
# 2       Census Tract 102.01, San Patricio County, Texas  0.708      52576
# 3         Census Tract 4209, Baltimore County, Maryland  0.485      74149
# 4         Census Tract 1104.03, Bulloch County, Georgia  0.367      49342
# ...                                                 ...    ...        ...
# 3979   Census Tract 9701, Webster County, West Virginia  0.683      41576
# 3980      Census Tract 9702, Richland County, Wisconsin  1.033      52738
# 3981        Census Tract 9748, Conejos County, Colorado  0.538      59448
# 3982           Census Tract 9602, Gooding County, Idaho  0.893      47334
# 3983           Census Tract 9670, Otoe County, Nebraska  0.791      52400
#
#       tractmhir  ...  BlackorA  AmericanI Asianalon  NativeHaw  TwoorMor  \
# 0         27143  ...      17.4        0.5       3.9        0.1       2.5
# 1         39558  ...       6.6        0.8       0.6        0.1       1.6
# 2         37231  ...       2.1        0.9       1.1        0.1       1.4
# 3         35996  ...      27.5        0.4       5.7        0.1       2.3
# 4         18103  ...      28.9        0.4       1.6        0.1       1.6
# ...         ...  ...       ...        ...       ...        ...       ...
# 3979      28416  ...       0.4        0.1       0.3        0.0       1.1
# 3980      54477  ...       0.6        0.4       0.6        0.0       0.9
# 3981      31957  ...       0.6        3.5       0.7        0.2       2.2
# 3982      42285  ...       0.5        1.8       0.8        0.2       1.8
# 3983      41424  ...       0.6        0.5       0.6        0.1       1.2
#
#       Hispanico  Whitealon  county         lon        lat
# 0          26.0       52.3  County  -82.430705  27.873952
# 1          11.8       79.4  County  -95.853592  32.211895
# 2          55.4       40.8  County  -97.244675  27.859829
# 3           4.8       60.5  County  -76.640195  39.463417
# 4           3.6       64.6  County  -81.743179  32.396803
# ...         ...        ...     ...         ...        ...
# 3979        0.4       97.7  County  -80.421865  38.494706
# 3980        2.2       95.4  County  -90.429483  43.375636
# 3981       53.9       43.6  County -106.191603  37.200716
# 3982       28.8       68.5  County -114.811564  42.970922
# 3983        6.5       90.8  County  -96.134765  40.648500
#
# [3984 rows x 66 columns]

# %%
data = data.dropna(subset=['ratio', 'Diversity', 'Asianalon', 'NativeHaw', 'TwoorMor', 'Hispanico', 'Whitealon'])

# %%
female_le_q2 = data['le_racea_4']

# %%
features = data[['ratio', 'Diversity', 'Asianalon', 'NativeHaw', 'TwoorMor', 'Hispanico', 'Whitealon']]

# %%
loc = data[['lon', 'lat']]

# %%
X_train, X_temp, y_train, y_temp, loc_train, loc_temp = train_test_split(features, female_le_q2, loc, train_size=0.8, random_state=42)

# %%
X_calib, X_test, y_calib, y_test, loc_calib, loc_test = train_test_split(X_temp, y_temp, loc_temp, train_size=0.5, random_state=42)

# %%
model = xgb.XGBRegressor(n_estimators=300, max_depth=2, min_child_weight=1, colsample_bytree=0.8)

# %%
model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=2, max_leaves=None,
#              min_child_weight=1, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=300, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
model.score(X_test, y_test)
# Out:
# 0.46910049898555595

# %%
from GeoConformal import GWQRBasedGeoConformalSpatialPrediction

# %%
geocp_spatial = GWQRBasedGeoConformalSpatialPrediction(predict_f=model.predict, nonconformity_score_f=None, miscoverage_level=0.1, alpha=0.0, coord_calib=loc_calib.values, coord_test=loc_test.values, x_calib=X_calib, y_calib=y_calib, x_test=X_test, y_test=y_test)

# %%
y_test.values[0]
# Out:
# 78.0094

# %%
results = geocp_spatial.analyze()
# Out:
# 100%|██████████| 399/399 [01:14<00:00,  5.32it/s]

# %%
results.coverage_probability
# Out:
# 0.9072681704260651

# %%
results.geo_uncertainty.mean() / 2
# Out:
# 45.55263169184439

# %%
geo_results = results.to_gpd()

# %%
utm = gcrs.WebMercator()

ax = gplt.webmap(geo_results, projection=utm, figsize=(14, 8), provider=cx.providers.CartoDB.Voyager)

gplt.pointplot(geo_results, hue='geo_uncertainty', cmap='viridis_r', legend=True, ax=ax)
# Out:
# <GeoAxes: >

# %%
from GeoConformal import GeoConformalSpatialPrediction

# %%
geocp_spatial_std = GeoConformalSpatialPrediction(predict_f=model.predict, nonconformity_score_f=None, miscoverage_level=0.1, bandwidth=3, coord_calib=loc_calib.values, coord_test=loc_test.values, X_calib=X_calib, y_calib=y_calib, X_test=X_test, y_test=y_test)

# %%
results_std = geocp_spatial_std.analyze()

# %%
results_std.coverage_probability
# Out:
# 0.9223057644110275

# %%
results_std.geo_uncertainty.mean()
# Out:
# 46.72197975955055
